# %%
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: matplotlib in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /home/buoffio/aspis_demo/ASPIS/.venv/lib/python3.10/site-packages (2.1.1)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
img_bw = np.loadtxt('image.dat') 
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(img_bw,cmap='gray')

# %%
foutput = 'lux_output.dat'
out = np.loadtxt(foutput)
plt.figure(figsize=(10,10))
plt.imshow(out,cmap='gray')

# %%
out = out/np.max(out)
thres = 0.075
out1 = np.where(out > thres, out ,1)
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(out1,cmap='gray')
